# %% [markdown]
# # Visualizing Earnings Based On College Majors

# %% [markdown]
# ## 1: Introduction To The Data
# In this project, we'll explore how using the pandas plotting functionality along with the Jupyter notebook interface allows us to explore data quickly using visualizations.
#
# We'll be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcomes was released by American Community Survey, which conducts surveys and aggregates the data. [FiveThirtyEight](http://fivethirtyeight.com/) cleaned the dataset and released it on their [Github repo](https://github.com/fivethirtyeight/data/blob/master/college-majors/recent-grads.csv).
#
# Each row in the dataset represents a different major in college and contains information on gender diversity, employment rates, median salaries, and more. Here are some of the columns in the dataset:
#
# * `Rank` - Rank by median earnings (the dataset is ordered by this column).
# * `Major_code` - Major code.
# * `Major` - Major description.
# * `Major_category` - Category of major.
# * `Total` - Total number of people with major.
# * `Sample_size` - Sample size (unweighted) of full-time.
# * `Men` - Male graduates.
# * `Women` - Female graduates.
# * `ShareWomen` - Women as share of total.
# * `Employed` - Number employed.
# * `Median` - Median salary of full-time, year-round workers.
# * `Low_wage_jobs` - Number in low-wage service jobs.
# * `Full_time` - Number employed 35 hours or more.
# * `Part_time` - Number employed less than 36 hours.
#
# Using visualizations, we can start to explore questions from the dataset like:
#
# * Do students in more popular majors make more money?
# * How many majors are predominantly male? Predominantly female?
# * Which category of majors have the most students?
#
#
# * Read the dataset into a DataFrame and start exploring the data.
#   * Read the `recent-grads.csv` dataset into a pandas DataFrame and assign the resulting DataFrame to `recent_grads`.
#   * Return the first row formatted as a table.
#   * Become familiar with the data structure.
#   * Generate summary statistics for all of the numeric columns.
# * Drop rows with missing values.

# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
recent_grads = pd.read_csv('data/recent-grads.csv')
print(recent_grads.iloc[0])
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Major_category                    Engineering
# Total                                    2339
# Sample_size                                36
# Men                                      2057
# Women                                     282
# ShareWomen                           0.120564
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
print(recent_grads.shape)
# Out:
# (173, 21)

# %%
print(recent_grads.head())
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2405                       CHEMICAL ENGINEERING    Engineering
#
#    Total  Sample_size    Men  Women  ShareWomen  Employed      ...        \
# 0   2339           36   2057    282    0.120564      1976      ...
# 1    756            7    679     77    0.101852       640      ...
# 2    856            3    725    131    0.153037       648      ...
# 3   1258           16   1123    135    0.107313       758      ...
# 4  32260          289  21239  11021    0.341631     25694      ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
print(recent_grads.tail())
# Out:
#      Rank  Major_code                   Major            Major_category  \
# 168   169        3609                 ZOOLOGY    Biology & Life Science
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  Psychology & Social Work
# 170   171        5202     CLINICAL PSYCHOLOGY  Psychology & Social Work
# 171   172        5203   COUNSELING PSYCHOLOGY  Psychology & Social Work
# 172   173        3501         LIBRARY SCIENCE                 Education
#
#      Total  Sample_size   Men  Women  ShareWomen  Employed      ...        \
# 168   8409           47  3050   5359    0.637293      6259      ...
# 169   2854            7   522   2332    0.817099      2125      ...
# 170   2838           13   568   2270    0.799859      2101      ...
# 171   4626           21   931   3695    0.798746      3777      ...
# 172   1098            2   134    964    0.877960       742      ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads = recent_grads.dropna()
print(recent_grads.shape)
# Out:
# (172, 21)

# %% [markdown]
# Only 1 row was dropped.

# %% [markdown]
# ## 2: Pandas, Scatter Plots
# We will generate scatter plots in separate jupyter notebook cells to explore the following relations:
# * `Total` and `Median`
# * `Total` and `Unemployment_rate`
# * `Full_time` and `Median`
# * `ShareWomen` and `Unemployment_rate`
# * `Men` and `Median`
# * `Women` and `Median`
#
# Use the plots to explore the following questions:
# * Do students in more popular majors make more money?
# * Do students that majored in subjects that were majority female make more money?
# * Is there any link between the number of full-time employees and median salary?

# %%
recent_grads.plot(x='Total', y='Median', kind='scatter')

# %% [markdown]
# We see a large range of median income (\$15000 to \$115000) at lower totals. As the popularity of the majors increases (i.e. higher Total), the median income seems to fall. The top 3 most popular majors have a median income range of \$30000 to \$40000.

# %%
recent_grads.plot(x='Total', y='Unemployment_rate', kind='scatter')

# %% [markdown]
# Do students select majors depending on the future job prospects? If that were true we should be seeing the least popular majors with high unemployment rates and the most popular majors with low unemployment rates.
# On the other hand, does the popularity of the major affect the demand-supply situation i.e. too many students in a certain major causing a glut of candidates in the job market with that job qualification?
# We see the data does not match up to either of the above assumptions. There is a large range of unemployment level (0.0 to 0.175) at lower Totals. As the popularity of the majors increases, they seem to fall in an unemployment range of 0.05 to 0.10.

# %%
recent_grads.plot(x='Full_time', y='Median', kind='scatter')

# %% [markdown]
# The median salary tends to get lower for majors with higher number of full time workers.

# %%
recent_grads.plot(x='ShareWomen', y='Unemployment_rate', kind='scatter')

# %% [markdown]
# There is no particular trend in Unemployment rate in relation to share of women in a major.
# The unemployment is scattered from 0.0 to 0.0175 independent of whether women form a majority (> 0.5) in a major or not.

# %%
recent_grads.plot(x='Men', y='Median', kind='scatter')

# %% [markdown]
# For men the median salary for most of the majors with >50000 students is in the range \$30000 to \$60000.

# %%
recent_grads.plot(x='Women', y='Median', kind='scatter')

# %% [markdown]
# For women the median salary for most of the majors with >50000 students is in the range \$30000 to \$50000.

# %% [markdown]
# ## 3: Pandas, Histograms
#
# Generate histograms in separate jupyter notebook cells to explore the distributions of the following columns:
# * `Sample_size`
# * `Median`
# * `Employed`
# * `Full_time`
# * `ShareWomen`
# * `Unemployment_rate`
# * `Men`
# * `Women`

# %%
cols = ["Sample_size", "Median", "Employed", "Full_time", "ShareWomen", "Unemployment_rate", "Men", "Women"]

fig = plt.figure(figsize=(5,25))
for r in range(0,8):
    ax = fig.add_subplot(8,1,r+1)
    ax = recent_grads[cols[r]].plot(kind='hist', rot=40)
    ax.set_title(cols[r])
    plt.tight_layout()
    plt.show()

# %% [markdown]
# \$30000-\$40000 is the most commmon median salary.
# The most frequent unemployment rate range is 0.06 to 0.08.

# %% [markdown]
# ## 4: Pandas, Scatter Matrix Plot
#
# * Create a 2 by 2 scatter matrix plot using the Total and Median columns.
# * Create a 3 by 3 scatter matrix plot using the Total, Median, and Unemployment_rate columns.

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(recent_grads[['Total', 'Median']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000268AD2C3DD8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000268AD1A70B8>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Total', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000268ADEBFC50>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000268ADAEFB00>]], dtype=object)

# %% [markdown]
# ## 5: Pandas, Bar Plots
#
# * Use bar plots to compare the percentages of women (ShareWomen) from the 10 highest paying majors and from the 10 lowest paying majors.
# * Use bar plots to compare the unemployment rate (Unemployment_rate) from the 10 highest paying majors and from the 10 lowest paying majors.

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=True)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=True)

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=True)
recent_grads[163:].plot.bar(x='Major', y='Unemployment_rate', legend=True)

# %% [markdown]
# ## 6: Next Steps
# We can keep exploring using other visualizations. Here are some ideas:
# * Use a grouped bar plot to compare the number of men with the number of women in each category of majors.
# * Use a box plot to explore the distributions of median salaries and unemployment rate.
